# %% [markdown]
# <div class="alert alert-block alert-info">
# <center> <h1> Exploratory Data Analysis (EDA) </h1> </center> <br>
# <center> <h2> Reading Files & Datasets </h2> </center> <br>
# <center> João Caldeira @ Universidade Lusófona </center>
# <center> 2023/2024 </center>

# %% [markdown]
# ## Este Notebook foi testado com Python 3.10.9 e está totalmente funcional.

# %% [markdown]
# <hr>
# <a class="anchor" id="setup">
#
# # 1. Configuração Inicial
# </a>

# %% [markdown]
# <a class="anchor" id="importlibraries">
#
# ## 1.1. Importar Livrarias/Pacotes e Definições Iniciais
#
# </a>
#
# Se as livrarias que necessitamos não estiverem instaladas, devemos instalá-las logo no ínicio.
# Esta ação só é executada uma vez, e assim sendo, o seguinte código, depois da primeira execução, deve ser comentado.

# %%
#%pip install pandas

# %% [markdown]
# Todas as livrarias que necessitarmos devem ser carregadas (desde que instaladas primeiro) logo no ínicio do Notebook.

# %%
import pandas as pd

# %% [markdown]
# <a class="anchor" id="importlibraries">
#
# ## 1.2. Importar os Dados
#
# </a>
#
# O segundo passo é carregar os dados com que queremos trabalhar. No caso de termos que lidar com um ficheiro de texto (ex: .txt, .csv), é fundamental não esquecer o separador das colunas. Abra o ficheiro no Wordpad ou Notepad e confirme o separador.

# %%
ds = pd.read_csv("datasets/titanic.csv")
ds.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
ds.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ## Import a CSV file (different delimiter)

# %%
ds = pd.read_csv("datasets/pt-real-state-sales-lisbon.csv", sep="|")
ds.head(10)
# Out:
#         id      city    osex   cyear    quality  year buyer.fname  \
# 0   PT-823    Lisboa    Male  1960.0    Perfect  2023       Tyler
# 1   PT-252       NaN     NaN  2003.0        NaN  2017     Sheldon
# 2   PT-528      Faro    Male  1920.0       High  2021     Breanna
# 3  PT-1312    Lisboa     NaN  1950.0        NaN  2018   Katherine
# 4    PT-25   Coimbra     NaN  1960.0     Medium  2020        Jose
# 5   PT-340       NaN     NaN  2017.0        NaN  2017    Malachai
# 6    PT-94    Lisboa     NaN  2014.0    Perfect  2020    Veronica
# 7  PT-1211     Porto     NaN  1975.0     Medium  2016        Eric
# 8  PT-1152  Portimão  Female  1998.0       High  2016      Sindel
# 9  PT-1039    Lisboa    Male     NaN  Very High  2018    Diocelin
#
#    buyer.lname  buyer.ethnicity  buyer.gender  buyer.age  \
# 0   Borovskikh                5             0         51
# 1      Cackler                1             0         32
# 2  Ortiz Munoz                4             1         39
# ...

# %% [markdown]
# ## Import a TXT file

# %%
ds = pd.read_csv("datasets/hr.txt", sep="\t")
ds.head(10)
# Out:
#      Emp_Id satisfaction_level last_evaluation  number_project  \
# 0  IND02438                38%             53%               2
# 1  IND28133                80%             86%               5
# 2  IND07164                11%             88%               7
# 3  IND30478                72%             87%               5
# 4  IND24003                37%             52%               2
# 5  IND08609                41%             50%               2
# 6  IND14345                10%             77%               6
# 7  IND16300                92%             85%               5
# 8  IND27336                89%            100%               5
# 9  IND41409                42%             53%               2
#
#    average_montly_hours  time_spend_company  Work_accident  left  \
# 0                   157                   3              0     1
# 1                   262                   6              0     1
# 2                   272                   4              0     1
# ...

# %% [markdown]
# ## Import a TSV file

# %%
ds = pd.read_csv("datasets/hr2.tsv", sep="\t")
ds.head(10)
# Out:
#      Emp_Id satisfaction_level last_evaluation  number_project  \
# 0  IND02438                38%             53%               2
# 1  IND28133                80%             86%               5
# 2  IND07164                11%             88%               7
# 3  IND30478                72%             87%               5
# 4  IND24003                37%             52%               2
# 5  IND08609                41%             50%               2
# 6  IND14345                10%             77%               6
# 7  IND16300                92%             85%               5
# 8  IND27336                89%            100%               5
# 9  IND41409                42%             53%               2
#
#    average_montly_hours  time_spend_company  Work_accident  left  \
# 0                   157                   3              0     1
# 1                   262                   6              0     1
# 2                   272                   4              0     1
# ...

# %% [markdown]
# ## Import an Excel file

# %%
#%pip install openpyxl
ds = pd.read_excel("datasets/hr.xlsx", sheet_name="F2")
ds.head(10)
# Out:
#      Emp_Id  satisfaction_level  last_evaluation  number_project  \
# 0  IND08609                0.41             0.50               2
# 1  IND14345                0.10             0.77               6
# 2  IND16300                0.92             0.85               5
# 3  IND27336                0.89             1.00               5
# 4  IND41409                0.42             0.53               2
# 5  IND01460                0.45             0.54               2
# 6  IND07665                0.11             0.81               6
# 7  IND13556                0.84             0.92               4
# 8  IND20559                0.41             0.55               2
# 9  IND12896                0.36             0.56               2
#
#    average_montly_hours  time_spend_company  Work_accident  left  \
# 0                   153                   3              0     1
# 1                   247                   4              0     1
# ...

# %% [markdown]
# ## Import a JSON file

# %%
ds = pd.read_json("datasets/data.json")
ds.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %% [markdown]
# ## Import data from Clipboard

# %%
Emp_Id	satisfaction_level	last_evaluation	number_project	average_montly_hours	time_spend_company	Work_accident	left	promotion_last_5years	Department	salary
IND02438	38%	53%	2	157	3	0	1	0	sales	low
IND28133	80%	86%	5	262	6	0	1	0	sales	medium

# %%
ds = pd.read_clipboard()
ds.head(10)
# Out:
#      Emp_Id satisfaction_level last_evaluation  number_project  \
# 0  IND02438                38%             53%               2
# 1  IND28133                80%             86%               5
#
#    average_montly_hours  time_spend_company  Work_accident  left  \
# 0                   157                   3              0     1
# 1                   262                   6              0     1
#
#    promotion_last_5years Department  salary
# 0                      0      sales     low
# 1                      0      sales  medium

# %% [markdown]
# ## Import a file from Internet

# %%
ds = pd.read_csv("https://raw.githubusercontent.com/jcppc/eda/main/datasets/hr.txt", sep="\t")
ds.head(10)
# Out:
#      Emp_Id satisfaction_level last_evaluation  number_project  \
# 0  IND02438                38%             53%               2
# 1  IND28133                80%             86%               5
# 2  IND07164                11%             88%               7
# 3  IND30478                72%             87%               5
# 4  IND24003                37%             52%               2
# 5  IND08609                41%             50%               2
# 6  IND14345                10%             77%               6
# 7  IND16300                92%             85%               5
# 8  IND27336                89%            100%               5
# 9  IND41409                42%             53%               2
#
#    average_montly_hours  time_spend_company  Work_accident  left  \
# 0                   157                   3              0     1
# 1                   262                   6              0     1
# 2                   272                   4              0     1
# ...

# %% [markdown]
# ## Import data from an HTML page

# %%
# %pip install lxml
ds = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')
ds
# Out:
# [                                            Minnesota  \
#  0                                               State
#  1   .mw-parser-output .ib-settlement-cols{text-ali...
#  2   Nicknames: Land of 10,000 Lakes; North Star St...
#  3   Motto: L'Étoile du Nord (French: The Star of t...
#  4                           Anthem: "Hail! Minnesota"
#  5   Map of the United States with Minnesota highli...
#  6                                             Country
#  7                                    Before statehood
#  8                               Admitted to the Union
#  9                                             Capital
#  10                                       Largest city
#  11                       Largest county or equivalent
#  12                      Largest metro and urban areas
#  13                                         Government
#  14                                         • Governor
#  15                              • Lieutenant Governor
# ...

# %%
ds = pd.read_html('https://en.wikipedia.org/wiki/Minnesota', match="Racial composition in 2020")[0]
ds
# Out:
#                         Race Percentage
# 0                      White      77.5%
# 1  Black or African American       7.0%
# 2            American Indian       1.2%
# 3                      Asian       5.3%
# 4           Pacific Islander       0.1%
# 5                 Other race       3.2%
# 6          Two or more races       6.1%

# %%
#%pip install html5lib
ds = pd.read_html('https://en.wikipedia.org/wiki/Minnesota', match="United States presidential election results for Minnesota")
ds[0].head()
# Out:
#    Year Republican         Democratic         Third party
#    Year        No.       %        No.       %         No.      %
# 0  2020    1484065  45.28%    1717077  52.40%       76029  2.32%
# 1  2016    1323232  44.93%    1367825  46.44%      254176  8.63%
# 2  2012    1320225  44.96%    1546167  52.65%       70169  2.39%
# 3  2008    1275409  43.82%    1573354  54.06%       61606  2.12%
# 4  2004    1346695  47.61%    1445014  51.09%       36678  1.30%

# %% [markdown]
# ## Import data from a database

# %%
import sqlite3

# Establish a connection to an SQLite database named 'database.db'
conn = sqlite3.connect('datasets/database.db')

# Define an SQL query to select all data from a table named 'table_name'
query = "SELECT * FROM students"

# Read data using the SQL query from the connection, creating a DataFrame 'ds'
ds = pd.read_sql(query, conn)
ds
# Out:
#    id           name
# 0   1  João Caldeira
# 1   2   Carlos Silva
# 2   3  José Oliveira
